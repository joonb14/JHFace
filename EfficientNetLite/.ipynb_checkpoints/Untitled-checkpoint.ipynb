# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
from efficientnet import *

# %%
model=EfficientNetLite0(input_shape=(112,112,3),include_top=False, weights=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-e1d14a48b1f0> in <module>
# ----> 1 model=EfficientNetLite0(input_shape=(112,112,3),include_top=False)
#
# /home/jbpark/workspace/tensorflow-test/keras-efficientNet/efficientnet.py in EfficientNetLite0(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation, **kwargs)
#     554       classes=classes,
#     555       classifier_activation=classifier_activation,
# --> 556       **kwargs)
#     557
#     558 def EfficientNetLite1(include_top=True,
#
# /home/jbpark/workspace/tensorflow-test/keras-efficientNet/efficientnet.py in EfficientNet(width_coefficient, depth_coefficient, default_size, dropout_rate, drop_connect_rate, depth_divisor, activation, blocks_args, model_name, include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     417     else:
# ...

# %%
model.summary()

# %%
checkpoint_path = "ckpt/efficientnet-lite0/model.ckpt"
model.load_weights(checkpoint_path)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/util.py:1315: NameBasedSaverStatus.__init__ (from tensorflow.python.training.tracking.util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Restoring a name-based tf.train.Saver checkpoint using the object-based restore API. This mode uses global names to match variables, and so is somewhat fragile. It also adds new restore ops to the graph each time it is called when graph building. Prefer re-encoding training checkpoints in the object-based format: run save() on the object-based saver (the same one this message is coming from) and use that checkpoint in the future.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-521085ecc7bc> in <module>
#       1 checkpoint_path = "ckpt/efficientnet-lite0/model.ckpt"
# ...
